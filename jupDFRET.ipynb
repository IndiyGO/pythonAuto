# %% [markdown]
# LEITURA DE DATAFRAME E CONSOLIDAÇÃO DOS DADOS DA RETENÇÃO

# %%
import pandas as pd
import openpyxl
import matplotlib.pyplot as plt
import numpy as np

WS = pd.read_excel('RETENÇÃO POWER BI.xlsx', sheet_name="WS")
ABO = pd.read_excel('RETENÇÃO POWER BI.xlsx', sheet_name="ABO")
KEN = pd.read_excel('RETENÇÃO POWER BI.xlsx', sheet_name="KEN")
SOB = pd.read_excel('RETENÇÃO POWER BI.xlsx', sheet_name="SOB")
JUA = pd.read_excel('RETENÇÃO POWER BI.xlsx', sheet_name="JUA")
THE = pd.read_excel('RETENÇÃO POWER BI.xlsx', sheet_name="THE")
THESUL = pd.read_excel('RETENÇÃO POWER BI.xlsx', sheet_name="THESUL")
PICOS = pd.read_excel('RETENÇÃO POWER BI.xlsx', sheet_name="PICOS")
PNB = pd.read_excel('RETENÇÃO POWER BI.xlsx', sheet_name="PNB")
JP = pd.read_excel('RETENÇÃO POWER BI.xlsx', sheet_name="JP")
CBD = pd.read_excel('RETENÇÃO POWER BI.xlsx', sheet_name="CBD")

df = pd.concat([WS, ABO, KEN, SOB, JUA,THE, THESUL, PICOS, PNB, JP, CBD])
df.to_excel('RetConsolidado.xlsx', index=False)

# %%
import pandas as pd
import openpyxl
import os
import shutil
Abol = pd.read_excel('RETENÇÃO POWER BI.xlsx', sheet_name="Abolição")
Was = pd.read_excel('RETENÇÃO POWER BI.xlsx', sheet_name="Washington Soares")
Juaz = pd.read_excel('RETENÇÃO POWER BI.xlsx', sheet_name="Juazeiro do Norte")
Kenn = pd.read_excel('RETENÇÃO POWER BI.xlsx', sheet_name="Kennedy")
Sobr = pd.read_excel('RETENÇÃO POWER BI.xlsx', sheet_name="Sobral")
Thez = pd.read_excel('RETENÇÃO POWER BI.xlsx', sheet_name="Teresina")
prnb = pd.read_excel('RETENÇÃO POWER BI.xlsx', sheet_name="Parnaíba")
picz = pd.read_excel('RETENÇÃO POWER BI.xlsx', sheet_name="Pic")
thes = pd.read_excel('RETENÇÃO POWER BI.xlsx', sheet_name="Teresina Sul")
jpa = pd.read_excel('RETENÇÃO POWER BI.xlsx', sheet_name="João Pessoa")
cbl = pd.read_excel('RETENÇÃO POWER BI.xlsx', sheet_name="Cabedelo")

df = pd.concat([Abol, Was, Juaz, Kenn, Sobr,Thez, prnb, picz,thes, jpa, cbl])
df.to_excel('RetConsol.xlsx', index=False)

# %% [markdown]
# CONCAT BASE JEEP APS

# %%
import pandas as pd
import openpyxl
import os
import shutil
var1 = pd.read_excel('APS_Premium.xlsx', sheet_name="JEEP JUA")
var2 = pd.read_excel('APS_Premium.xlsx', sheet_name="JEEP JP")
var3 = pd.read_excel('APS_Premium.xlsx', sheet_name ="JEEP SOB")
var4 = pd.read_excel('APS_Premium.xlsx', sheet_name ="JEEP FOR")
var5 = pd.read_excel('APS_Premium.xlsx', sheet_name ="JEEP CBD")


df = pd.concat([var1, var2, var3,var4, var5])
df.to_excel('apsJeep.xlsx', index=False)

# %%
import pandas as pd
import openpyxl
import os
import shutil
var1 = pd.read_excel('APS_Premium.xlsx', sheet_name="MBB THE")
var2 = pd.read_excel('APS_Premium.xlsx', sheet_name="MBB FOR")
var3 = pd.read_excel('APS_Premium.xlsx', sheet_name="MBB JPA")


df = pd.concat([var1, var2, var3])
df.to_excel('apsMBB.xlsx', index=False)

# %%
import pandas as pd

var1 = pd.read_excel('APS.xlsx',sheet_name="JPA")
var2 = pd.read_excel('APS.xlsx',sheet_name="WS")
var3 = pd.read_excel('APS.xlsx',sheet_name="ABO")
var4 = pd.read_excel('APS.xlsx',sheet_name="KND")
var5 = pd.read_excel('APS.xlsx',sheet_name="CBD")
var6 = pd.read_excel('APS.xlsx',sheet_name="JUA")
var7 = pd.read_excel('APS.xlsx',sheet_name="PNB")
var8 = pd.read_excel('APS.xlsx',sheet_name="PIC")
var9 = pd.read_excel('APS.xlsx',sheet_name="SOB")
var10 = pd.read_excel('APS.xlsx',sheet_name="SVC")
var11 = pd.read_excel('APS.xlsx',sheet_name="THE")
var12 = pd.read_excel('APS.xlsx',sheet_name="THES")



data = pd.concat([var1,var2,var3,var4,var5,var6,var7,var8,var9,var10,var11,var12])
data['OPERADOR'].replace(['LARISSA ', 'GARDENIA ', 'JEFFERSON '],['LARISSA', 'GARDENIA', 'JEFFERSON']inplace=True)
data.to_excel('apsConcat.xlsx',index=False)

# %%
import urllib.request
from bs4 import BeautifulSoup

wiki = 'https://pt.wikipedia.org/wiki/Airbus_A380'
page = urllib.request.urlopen(wiki)
soup = BeautifulSoup(page, 'html.parser')
table = soup.find('table')
print(table)

A=[]
B=[]
C=[]
D=[]
E=[]

for row in table.findAll('tr'):
    cells = row.findAll('td')
    if len(cells)==5: 
        A.append(cells[0].find(text=True))
        B.append(cells[1].find(text=True))
        C.append(cells[2].find(text=True))
        D.append(cells[3].find('a').text)
        E.append(cells[4].find(text=True))

import pandas as pd

df = pd.DataFrame(index=A, columns=['Posição'])

df['2001']=A
df['2002']=B
df['2003']=C
df['2004']=D
df['2005']=E

df

# %% [markdown]
# VERIFICAR DATAFRAME

# %%
import pandas as pd
import openpyxl

vt = pd.read_excel('RetConsolidado.xlsx' )
vt.tail()

# %%
import pandas as pd
import openpyxl
import os
import shutil

A = pd.read_excel('apvABO.xlsx')
B = pd.read_excel("apvCBD.xlsx", sheet_name="Sheet1")
C = pd.read_excel('apvJP.xlsx', sheet_name="Sheet1")
D = pd.read_excel('apvJUA.xlsx', sheet_name="Sheet1")
F = pd.read_excel('apvKEN.xlsx', sheet_name="Sheet1")
G = pd.read_excel('apvPIC.xlsx', sheet_name="Sheet1")
H = pd.read_excel('apvPNB.xlsx', sheet_name="Sheet1")
I = pd.read_excel('apvSOB.xlsx', sheet_name="Sheet1")
J = pd.read_excel('apvTHE.xlsx', sheet_name="Sheet1")
K = pd.read_excel('apvTHESUL.xlsx', sheet_name="Sheet1")
L = pd.read_excel('apvWS.xlsx', sheet_name="Sheet1")

df = pd.concat([A, B, C, D, F, G, H, I, J, K, L])
df.to_excel('relatACO', index=False)

# %%
import pandas as pd
import openpyxl

vt = pd.read_excel('recallMerc.xlsx')
vt.tail()

# %%
import pyautogui
import time
import pandas as pd
import shutil


path1 = '/Users/jpsantos/Downloads/APS.xlsx'
path2 = '/Users/jpsantos/Desktop/BI RET/'

pyautogui.press('win')
time.sleep(1)
pyautogui.typewrite('Chrome')
time.sleep(1)
pyautogui.press('enter')
time.sleep(8)
pyautogui.click(x=79, y=82)
time.sleep(20)
pyautogui.click(x=29, y=162)
time.sleep(10)
pyautogui.click(x=89, y=360)
time.sleep(5)
pyautogui.click(x=277, y=224)
time.sleep(20)

shutil.move(path1, path2)

time.sleep(3)

var1 = pd.read_excel('APS.xlsx',sheet_name="JPA")
var2 = pd.read_excel('APS.xlsx',sheet_name="WS")
var3 = pd.read_excel('APS.xlsx',sheet_name="ABO")
var4 = pd.read_excel('APS.xlsx',sheet_name="KND")
var5 = pd.read_excel('APS.xlsx',sheet_name="CBD")
var6 = pd.read_excel('APS.xlsx',sheet_name="JUA")
var7 = pd.read_excel('APS.xlsx',sheet_name="PNB")
var8 = pd.read_excel('APS.xlsx',sheet_name="PIC")
var9 = pd.read_excel('APS.xlsx',sheet_name="SOB")
var10 = pd.read_excel('APS.xlsx',sheet_name="SVC")
var11 = pd.read_excel('APS.xlsx',sheet_name="THE")
var12 = pd.read_excel('APS.xlsx',sheet_name="THES")

data = pd.concat([var1,var2,var3,var4,var5,var6,var7,var8,var9,var10,var11,var12])
data.to_excel('apsConcat.xlsx',index=False)

# %%
import pandas as pd
import pyautogui
import time
import os
import shutil
import datetime

hoje = datetime.date.today()
dia_anterior = hoje - datetime.timedelta(days=1)
data_formatada = dia_anterior.strftime("%d/%m/%Y")
data_formatada2 = hoje.strftime("%d/%m/%Y")
path1 = 'Q:/CRM JP/rankTOY.xlsx'
path2 = '/Users/jpsantos/Desktop/'

pyautogui.press('win')
time.sleep(2)
pyautogui.typewrite('chrome')
time.sleep(2)
pyautogui.press('enter')
time.sleep(3)
pyautogui.click(x=213, y=86)
time.sleep(5)
pyautogui.click(x=635, y=339)
pyautogui.typewrite('374306')
time.sleep(5)
pyautogui.press('enter')
time.sleep(20)
pyautogui.click(x=663, y=385)
time.sleep(3)
pyautogui.typewrite('MICHAELC')
time.sleep(3)
pyautogui.click(x=660, y=420)
time.sleep(3)
pyautogui.typewrite('374306')
time.sleep(2)
pyautogui.click(x=719, y=498)
time.sleep(2)
pyautogui.click(x=753, y=409)
time.sleep(2)
pyautogui.click(x=693, y=447)
time.sleep(2)
pyautogui.press('enter')
time.sleep(2)
pyautogui.click(x=1208, y=679)
time.sleep(5)
pyautogui.click(x=1270, y=363)
time.sleep(5)
pyautogui.click(x=552, y=168)
time.sleep(5)
pyautogui.click(x=584, y=235)
time.sleep(5)
pyautogui.click(x=465, y=176)
time.sleep(5)
pyautogui.click(x=480, y=175)
time.sleep(2)
pyautogui.typewrite(data_formatada2)
pyautogui.click(x=465, y=200)
time.sleep(2)
pyautogui.click(x=482, y=198)
time.sleep(2)
pyautogui.typewrite(data_formatada2)
pyautogui.click(x=1184, y=192)
pyautogui.click(x=814, y=218)
pyautogui.click(x=1098, y=182)
pyautogui.click(x=1100, y=200)
pyautogui.click(x=1098, y=217)
pyautogui.click(x=1184, y=192)
time.sleep(5)
pyautogui.click(x=181, y=666)
time.sleep(5)
pyautogui.click(x=455, y=246)
time.sleep(1)
pyautogui.click(x=457, y=269)
time.sleep(1)
pyautogui.click(x=694, y=315)
time.sleep(1)
pyautogui.click(x=671, y=420)
time.sleep(1)
pyautogui.click(x=671, y=420)
time.sleep(1)
pyautogui.click(x=607, y=641)
time.sleep(1)
pyautogui.click(x=865, y=252)
time.sleep(1)
pyautogui.typewrite('Q:\CRM JP')
pyautogui.press('enter')
time.sleep(1)
pyautogui.click(x=707, y=582)
time.sleep(1)
pyautogui.typewrite('rankToy.xlsx')
time.sleep(1)
pyautogui.press('enter')
pyautogui.press('tab')
time.sleep(1)
pyautogui.press('enter')
time.sleep(2)
shutil.move(path1, path2)

# %%
import time
import datetime
import pandas as pd

hoje = datetime.date.today()
dia_anterior = hoje - datetime.timedelta(days=1)
data_formatada = dia_anterior.strftime("%m/%d/%Y")
hoje_formatado = hoje.strftime("%m/%d/%Y")

var1 = pd.read_excel('APS.xlsx',sheet_name="JPA")
var2 = pd.read_excel('APS.xlsx',sheet_name="WS")
var3 = pd.read_excel('APS.xlsx',sheet_name="ABO")
var4 = pd.read_excel('APS.xlsx',sheet_name="KND")
var5 = pd.read_excel('APS.xlsx',sheet_name="CBD")
var6 = pd.read_excel('APS.xlsx',sheet_name="JUA")
var7 = pd.read_excel('APS.xlsx',sheet_name="PNB")
var8 = pd.read_excel('APS.xlsx',sheet_name="PIC")
var9 = pd.read_excel('APS.xlsx',sheet_name="SOB")
var10 = pd.read_excel('APS.xlsx',sheet_name="SVC")
var11 = pd.read_excel('APS.xlsx',sheet_name="THE")
var12 = pd.read_excel('APS.xlsx',sheet_name="THES")

data = pd.concat([var1,var2,var3,var4,var5,var6,var7,var8,var9,var10,var11,var12])
data['Data'] = pd.to_datetime(data['Data'])
filtered_df = data.loc[(data['Data'] <= hoje_formatado)]
filtered_df.to_excel('apsFiltrado.xlsx', index=False)

# %%
import pyautogui
import time

# Open the source Excel file
pyautogui.press('win')
pyautogui.typewrite('Base APS.xlsx')
pyautogui.press('enter')
time.sleep(5)
pyautogui.hotkey('ctrl', 'o')
pyautogui.typewrite('path/to/source/file.xlsx')
pyautogui.press('enter')
time.sleep(2) 

# Select and copy the data
pyautogui.click(x=100, y=200) # Replace with the coordinates of the cell containing the data
pyautogui.hotkey('ctrl', 'shift', 'end')
pyautogui.hotkey('ctrl', 'c')

# Open the target Excel file
pyautogui.press('win')
pyautogui.typewrite('Excel')
pyautogui.press('enter')
time.sleep(5) # Wait for Excel to open
pyautogui.hotkey('ctrl', 'o')
pyautogui.typewrite('path/to/target/file.xlsx')
pyautogui.press('enter')
time.sleep(2) # Wait for the file to open

# Paste the data
pyautogui.click(x=300, y=400) # Replace with the coordinates of the cell where you want to paste the data
pyautogui.hotkey('ctrl', 'v')

# %%
import pandas as pd
import pyautogui
import time
import os
import shutil

path1 = '/Users/jpsantos/Downloads/RETENÇÃO POWER BI.xlsx'
path2 = '/Users/jpsantos/Desktop/BI RET/'

#Download Retenção
pyautogui.press('win')
time.sleep(1)
pyautogui.typewrite('Chrome')
time.sleep(1)
pyautogui.press('enter')
time.sleep(15)
pyautogui.click(x=295, y=87)
time.sleep(15)
pyautogui.click(x=29, y=162)
time.sleep(10)
pyautogui.click(x=89, y=360)
time.sleep(10)
pyautogui.click(x=308, y=365)
time.sleep(30)

#Copiar planilha
shutil.move(path1, path2)

time.sleep(3)

#Concatenar Planilhas

Abol = pd.read_excel('RETENÇÃO POWER BI.xlsx', sheet_name="Abolição")
Was = pd.read_excel('RETENÇÃO POWER BI.xlsx', sheet_name="Washington Soares")
Juaz = pd.read_excel('RETENÇÃO POWER BI.xlsx', sheet_name="Juazeiro do Norte")
Kenn = pd.read_excel('RETENÇÃO POWER BI.xlsx', sheet_name="Kennedy")
Sobr = pd.read_excel('RETENÇÃO POWER BI.xlsx', sheet_name="Sobral")
Thez = pd.read_excel('RETENÇÃO POWER BI.xlsx', sheet_name="Teresina")
prnb = pd.read_excel('RETENÇÃO POWER BI.xlsx', sheet_name="Parnaíba")
picz = pd.read_excel('RETENÇÃO POWER BI.xlsx', sheet_name="Pic")
thes = pd.read_excel('RETENÇÃO POWER BI.xlsx', sheet_name="Teresina Sul")
jpa = pd.read_excel('RETENÇÃO POWER BI.xlsx', sheet_name="João Pessoa")
cbl = pd.read_excel('RETENÇÃO POWER BI.xlsx', sheet_name="Cabedelo")

df = pd.concat([Abol, Was, Juaz, Kenn, Sobr,Thez, prnb, picz,thes, jpa, cbl])
df.to_excel('RetConsol.xlsx', index=False)

#Inserir Tabela

pyautogui.press('win')
time.sleep(1)
pyautogui.typewrite('RetConsol')
time.sleep(1)
pyautogui.press('enter')
time.sleep(10)
pyautogui.hotkey('ctrl','q')
time.sleep(1)
pyautogui.press('right')
pyautogui.press('right')
pyautogui.press('right')
pyautogui.press('tab')
pyautogui.press('enter')
time.sleep(5)
pyautogui.hotkey('ctrl','b')
time.sleep(5)

# %%
import pandas as pd
import pyautogui
import time
import os
import shutil

# %%
import pandas as pd
import pyautogui
import time
import os
import shutil
import datetime



hoje = datetime.date.today()
dia_anterior = hoje - datetime.timedelta(days=2)
data_formatada = dia_anterior.strftime("%d/%m/%Y")

path1 = 'Q:/CRM JP/rankJEEP.xlsx'
path2 = '/Users/jpsantos/Desktop/'


pyautogui.press('win')
time.sleep(1)
pyautogui.typewrite('chrome')
time.sleep(1)
pyautogui.press('enter')
time.sleep(3)
pyautogui.click(x=213, y=86)
time.sleep(5)
pyautogui.click(x=635, y=339)
pyautogui.typewrite('374306')
time.sleep(5)
pyautogui.press('enter')
time.sleep(20)
pyautogui.click(x=663, y=385)
time.sleep(3)
pyautogui.typewrite('MICHAELC')
time.sleep(3)
pyautogui.click(x=660, y=420)
time.sleep(3)
pyautogui.typewrite('374306')
time.sleep(2)
pyautogui.click(x=719, y=498)
time.sleep(2)
pyautogui.press('enter')
time.sleep(2)
pyautogui.click(x=1208, y=679)
time.sleep(5)
pyautogui.click(x=1270, y=363)
time.sleep(5)
pyautogui.click(x=552, y=168)
time.sleep(5)
pyautogui.click(x=584, y=235)
time.sleep(5)
pyautogui.click(x=465, y=176)
time.sleep(5)
pyautogui.click(x=480, y=175)
time.sleep(2)
pyautogui.typewrite(data_formatada)
pyautogui.click(x=465, y=200)
time.sleep(2)
pyautogui.click(x=482, y=198)
time.sleep(2)
pyautogui.typewrite(data_formatada)
pyautogui.click(x=1184, y=192)
time.sleep(1)
pyautogui.click(x=814, y=218)
time.sleep(1)
pyautogui.click(x=1098, y=182)
time.sleep(1)
pyautogui.click(x=1100, y=200)
time.sleep(1)
pyautogui.click(x=1098, y=217)
time.sleep(1)
pyautogui.click(x=1184, y=192)
time.sleep(5)
pyautogui.click(x=181, y=666)
time.sleep(5)
pyautogui.click(x=455, y=246)
time.sleep(1)
pyautogui.click(x=457, y=269)
time.sleep(1)
pyautogui.click(x=694, y=315)
time.sleep(1)
pyautogui.click(x=671, y=420)
time.sleep(1)
pyautogui.click(x=671, y=420)
time.sleep(1)
pyautogui.click(x=607, y=641)
time.sleep(1)
pyautogui.click(x=865, y=252)
time.sleep(1)
pyautogui.typewrite('Q:\CRM JP')
pyautogui.press('enter')
time.sleep(1)
pyautogui.click(x=707, y=582)
time.sleep(1)
pyautogui.typewrite('rankJEEP.xlsx')
time.sleep(1)
pyautogui.press('enter')
pyautogui.press('tab')
time.sleep(1)
pyautogui.press('enter')
time.sleep(2)
shutil.move(path1, path2)

# %%
import pandas as pd
import pyautogui
import time
import os
import shutil
import datetime



hoje = datetime.date.today()
dia_anterior = hoje - datetime.timedelta(days=2)
data_formatada = dia_anterior.strftime("%d/%m/%Y")

path1 = 'Q:/CRM JP/rankJEEP.xlsx'
path2 = '/Users/jpsantos/Desktop/'


pyautogui.press('win')
time.sleep(1)
pyautogui.typewrite('chrome')
time.sleep(1)
pyautogui.press('enter')
time.sleep(3)
pyautogui.click(x=213, y=86)
time.sleep(5)
pyautogui.click(x=635, y=339)
pyautogui.typewrite('374306')
time.sleep(5)
pyautogui.press('enter')
time.sleep(20)
pyautogui.click(x=663, y=385)
time.sleep(3)
pyautogui.typewrite('MICHAELC')
time.sleep(3)
pyautogui.click(x=660, y=420)
time.sleep(3)
pyautogui.typewrite('374306')
time.sleep(2)
pyautogui.click(x=719, y=498)
time.sleep(2)
pyautogui.press('enter')
time.sleep(2)
pyautogui.click(x=1208, y=679)
time.sleep(5)
pyautogui.click(x=1270, y=363)
time.sleep(5)
pyautogui.click(x=552, y=168)
time.sleep(5)
pyautogui.click(x=584, y=235)
time.sleep(5)
pyautogui.click(x=465, y=176)
time.sleep(5)
pyautogui.click(x=480, y=175)
time.sleep(2)
pyautogui.typewrite(data_formatada)
pyautogui.click(x=465, y=200)
time.sleep(2)
pyautogui.click(x=482, y=198)
time.sleep(2)
pyautogui.typewrite(data_formatada)
pyautogui.click(x=1184, y=192)
time.sleep(1)
pyautogui.click(x=814, y=218)
time.sleep(1)
pyautogui.click(x=1098, y=182)
time.sleep(1)
pyautogui.click(x=1100, y=200)
time.sleep(1)
pyautogui.click(x=1098, y=217)
time.sleep(1)
pyautogui.click(x=1184, y=192)
time.sleep(5)
pyautogui.click(x=181, y=666)
time.sleep(5)
pyautogui.click(x=455, y=246)
time.sleep(1)
pyautogui.click(x=457, y=269)
time.sleep(1)
pyautogui.click(x=694, y=315)
time.sleep(1)
pyautogui.click(x=671, y=420)
time.sleep(1)
pyautogui.click(x=671, y=420)
time.sleep(1)
pyautogui.click(x=607, y=641)
time.sleep(1)
pyautogui.click(x=865, y=252)
time.sleep(1)
pyautogui.typewrite('Q:\CRM JP')
pyautogui.press('enter')
time.sleep(1)
pyautogui.click(x=707, y=582)
time.sleep(1)
pyautogui.typewrite('rankJEEP.xlsx')
time.sleep(1)
pyautogui.press('enter')
pyautogui.press('tab')
time.sleep(1)
pyautogui.press('enter')
time.sleep(2)
shutil.move(path1, path2)

# %%
import shutil
import os

path1 = '/Users/jpsantos/Downloads/RETENÇÃO POWER BI.xlsx'
path2 = '/Users/jpsantos/Desktop/BI RET/'

shutil.move(path1, path2)

# %%
import shutil
import os

path1 = '/Users/jpsantos/Downloads/APS.xlsx'
path2 = '/Users/jpsantos/Desktop/BI RET/'

shutil.move(path1, path2)

# %%
import pyautogui
import time

time.sleep(3)

pyautogui.position()
# Out:
# Point(x=1275, y=427)

# %%
import openpyxl
import pandas as pd

ret1 = pd.read_excel('ret1.xlsx')
ret2 = pd.read_excel('ret2.xlsx')

df = pd.concat([ret1, ret2])
df.to_excel('retFinal.xlsx', index=False)

# %%
import pandas as pd

KND2 = pd.read_excel('APS.xlsx', sheet_name="KND")
ABO2 = pd.read_excel('APS.xlsx', sheet_name="ABO")
CBD2 = pd.read_excel('APS.xlsx', sheet_name="CBD")
JPA2 = pd.read_excel('APS.xlsx', sheet_name="JPA")
JUA2 = pd.read_excel('APS.xlsx', sheet_name="JUA")
PIC2 = pd.read_excel('APS.xlsx', sheet_name="PIC")
PNB2 = pd.read_excel('APS.xlsx', sheet_name="PNB")
SOB2 = pd.read_excel('APS.xlsx', sheet_name="SOB")
SVC2 = pd.read_excel('APS.xlsx', sheet_name="SVC")
THE2 = pd.read_excel('APS.xlsx', sheet_name="THE")
THES2 = pd.read_excel('APS.xlsx', sheet_name="THES")
WS2 = pd.read_excel('APS.xlsx', sheet_name="WS")

df = pd.concat([KND2, ABO2, CBD2, JPA2, JUA2,PIC2, PNB2, SOB2,SVC2, THE2, THES2, WS2])
df.to_excel('apsToyConsol.xlsx', index=False)

# %%
import pytesseract
import cv2

imagem = cv2.imread("img1.png")

caminho = "/Users/jpsantos/Desktop/BI RET"
pytesseract.pytesseract.tesseract_cmd = caminho + '/tesseract.exe'
texto = pytesseract.image_to_string(imagem, lang="por") #
print(texto)

# %%
import requests
from bs4 import BeautifulSoup

# Send a request to the dashboard
req = requests.get("https://stheel.sac.digital/relatorio/atendimentos")

# Parse the HTML content of the dashboard
soup = BeautifulSoup(req.content, 'html.parser')

# Extract the data from the dashboard
data = soup.find_all('div', class_="data")

# Print the extracted data
for d in data:
    print(d.text)
